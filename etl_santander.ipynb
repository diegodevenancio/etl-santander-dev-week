# %%
import pandas as pd

# %%
df = pd.read_csv('SDW2023.csv')

users = df.to_dict(orient='records')

for user in users:
    user['news'] = []

users
# Out:
# [{'id': 1, 'name': 'Ana', 'news': []},
#  {'id': 2, 'name': 'Carlos', 'news': []},
#  {'id': 3, 'name': 'Mariana', 'news': []},
#  {'id': 4, 'name': 'João', 'news': []},
#  {'id': 5, 'name': 'Beatriz', 'news': []}]

# %%
def generate_ai_news(user):
    return f"{user['name']}, investir hoje é o primeiro passo para um futuro financeiro seguro."

for user in users:
    news = generate_ai_news(user)
    user['news'].append({
        "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
        "description": news
    })

users
# Out:
# [{'id': 1,
#   'name': 'Ana',
#   'news': [{'icon': 'https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg',
#     'description': 'Ana, investir hoje é o primeiro passo para um futuro financeiro seguro.'}]},
#  {'id': 2,
#   'name': 'Carlos',
#   'news': [{'icon': 'https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg',
#     'description': 'Carlos, investir hoje é o primeiro passo para um futuro financeiro seguro.'}]},
#  {'id': 3,
#   'name': 'Mariana',
#   'news': [{'icon': 'https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg',
#     'description': 'Mariana, investir hoje é o primeiro passo para um futuro financeiro seguro.'}]},
#  {'id': 4,
#   'name': 'João',
#   'news': [{'icon': 'https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg',
#     'description': 'João, investir hoje é o primeiro passo para um futuro financeiro seguro.'}]},
#  {'id': 5,
#   'name': 'Beatriz',
#   'news': [{'icon': 'https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg',
#     'description': 'Beatriz, investir hoje é o primeiro passo para um futuro financeiro seguro.'}]}]

# %%
import json

with open('users_with_news.json', 'w', encoding='utf-8') as f:
    json.dump(users, f, ensure_ascii=False, indent=2)

print("Arquivo users_with_news.json gerado com sucesso!")
# Out:
# Arquivo users_with_news.json gerado com sucesso!
